# %%
import pandas as pd

# %%
# After few lines we reset index_col
movies_data = pd.read_csv("tmdb_5000_movies.csv", index_col = 'original_title')

# %%
type(movies_data)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data.shape
# Out:
# (4803, 19)

# %%
movies_data.head(2)
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                                                               homepage  \
# original_title
# Avatar                                                     http://www.avatarmovie.com/
# Pirates of the Caribbean: At World's End  http://disney.go.com/disneypictures/pirates/
#
#                                              id  \
# original_title
# Avatar                                    19995
# Pirates of the Caribbean: At World's End    285
#
# ...

# %%
movies_data.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
movies_data.index
# Out:
# Index(['Avatar', 'Pirates of the Caribbean: At World's End', 'Spectre',
#        'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled',
#        'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince',
#        'Batman v Superman: Dawn of Justice',
#        ...
#        'On The Downlow', 'Sanctuary: Quite a Conundrum', 'Bang', 'Primer',
#        'Cavite', 'El Mariachi', 'Newlyweds', 'Signed, Sealed, Delivered',
#        'Shanghai Calling', 'My Date with Drew'],
#       dtype='object', name='original_title', length=4803)

# %%
movies_data[['budget', 'runtime', 'popularity', 'vote_average']]
# Out:
#                                              budget  runtime  popularity  \
# original_title
# Avatar                                    237000000    162.0  150.437577
# Pirates of the Caribbean: At World's End  300000000    169.0  139.082615
# Spectre                                   245000000    148.0  107.376788
# The Dark Knight Rises                     250000000    165.0  112.312950
# John Carter                               260000000    132.0   43.926995
# ...                                             ...      ...         ...
# El Mariachi                                  220000     81.0   14.269792
# Newlyweds                                      9000     85.0    0.642552
# Signed, Sealed, Delivered                         0    120.0    1.444476
# Shanghai Calling                                  0     98.0    0.857008
# My Date with Drew                                 0     90.0    1.929883
#
#                                           vote_average
# original_title
# ...

# %%
new_df = movies_data[['budget', 'runtime', 'popularity', 'vote_average']]

# %%
new_df.sum().popularity
# Out:
# 103227.51972500015

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4803 entries, Avatar to My Date with Drew
# Data columns (total 19 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# id                      4803 non-null int64
# keywords                4803 non-null object
# original_language       4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# vote_average            4803 non-null float64
# ...

# %%
movies_data[0:1]
# Out:
#                    budget                                             genres  \
# original_title
# Avatar          237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                    homepage     id  \
# original_title
# Avatar          http://www.avatarmovie.com/  19995
#
#                                                          keywords  \
# original_title
# Avatar          [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                original_language  \
# original_title
# Avatar                        en
#
#                                                          overview  popularity  \
# original_title
# Avatar          In the 22nd century, a paraplegic Marine is di...  150.437577
#
#                                              production_companies  \
# original_title
# Avatar          [{"name": "Ingenious Film Partners", "id": 289...
#
#                                              production_countries  \
# original_title
# ...

# %%
movies_data.iloc[1:3]
# Out:
#                                              budget  \
# original_title
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
#
#                                                                                      genres  \
# original_title
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# Spectre                                   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                                               homepage  \
# original_title
# Pirates of the Caribbean: At World's End  http://disney.go.com/disneypictures/pirates/
# Spectre                                    http://www.sonypictures.com/movies/spectre/
#
#                                               id  \
# original_title
# Pirates of the Caribbean: At World's End     285
# Spectre                                   206647
#
# ...

# %%
movies_data.iloc[[0,1,5,9], [0,7]]
# Out:
#                                              budget  popularity
# original_title
# Avatar                                    237000000  150.437577
# Pirates of the Caribbean: At World's End  300000000  139.082615
# Spider-Man 3                              258000000  115.699814
# Batman v Superman: Dawn of Justice        250000000  155.790452

# %%
movies_data.iloc[[0,1,5,9], 0:4]
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spider-Man 3                              258000000
# Batman v Superman: Dawn of Justice        250000000
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# Spider-Man 3                              [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# Batman v Superman: Dawn of Justice        [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                                                  homepage  \
# original_title
# Avatar                                                        http://www.avatarmovie.com/
# ...

# %%
#movies_data.loc[['Avatar', 'Spider-Man 3'], ['release_date','popularity']]

# %%
movies_data.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
movies_data.reset_index(inplace = True)

# %%
movies_data.head(3)
# Out:
#                              original_title     budget  \
# 0                                    Avatar  237000000
# 1  Pirates of the Caribbean: At World's End  300000000
# 2                                   Spectre  245000000
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
# ...

# %%
movies_data.loc[0:3 , ['original_title', 'budget']]
# Out:
#                              original_title     budget
# 0                                    Avatar  237000000
# 1  Pirates of the Caribbean: At World's End  300000000
# 2                                   Spectre  245000000
# 3                     The Dark Knight Rises  250000000

# %%
movies_data.loc[0:3]
# Out:
#                              original_title     budget  \
# 0                                    Avatar  237000000
# 1  Pirates of the Caribbean: At World's End  300000000
# 2                                   Spectre  245000000
# 3                     The Dark Knight Rises  250000000
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
#
#                                             keywords original_language  \
# ...

# %%
movies_data.iloc[[1,2,5,8,9,7], 1:5]
# Out:
#       budget                                             genres  \
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# 5    http://www.sonypictures.com/movies/spider-man3/     559
# 8  http://harrypotter.warnerbros.com/harrypottera...     767
# 9       http://www.batmanvsupermandawnofjustice.com/  209112
# 7  http://marvel.com/movies/movie/193/avengers_ag...   99861

# %%
movies_data.nunique()
# Out:
# original_title          4801
# budget                   436
# genres                  1175
# homepage                1691
# id                      4803
# keywords                4222
# original_language         37
# overview                4800
# popularity              4802
# production_companies    3697
# production_countries     469
# release_date            3280
# revenue                 3297
# runtime                  156
# spoken_languages         544
# status                     3
# tagline                 3944
# title                   4800
# vote_average              71
# vote_count              1609
# dtype: int64

# %%
ser = movies_data['runtime']

# %%
ser.value_counts()
# Out:
# 90.0     163
# 100.0    149
# 98.0     140
# 97.0     133
# 95.0     123
#         ...
# 338.0      1
# 53.0       1
# 214.0      1
# 194.0      1
# 179.0      1
# Name: runtime, Length: 156, dtype: int64

# %%
ser.value_counts(ascending = True)
# Out:
# 179.0      1
# 194.0      1
# 214.0      1
# 53.0       1
# 338.0      1
#         ...
# 95.0     123
# 97.0     133
# 98.0     140
# 100.0    149
# 90.0     163
# Name: runtime, Length: 156, dtype: int64

# %%
ser.value_counts(ascending = False, bins = 3)
# Out:
# (-0.339, 112.667]     3245
# (112.667, 225.333]    1548
# (225.333, 338.0]         8
# Name: runtime, dtype: int64

# %%
anime = ['My hero Academia', 'Death note', 'Sword Art online', 'One-punch Man', 'Domestic Girlfriend', 'youri on ice', 'Doraemon']
genre = ['shounen', 'shuonen', 'Action Adventure', 'action', 'shuonen/shoujo', 'Sports/josei', 'kodomomuke']

# %%
anime_series = pd.Series(anime, name = 'Anime Genre')
anime_series
# Out:
# 0       My hero Academia
# 1             Death note
# 2       Sword Art online
# 3          One-punch Man
# 4    Domestic Girlfriend
# 5           youri on ice
# 6               Doraemon
# Name: Anime Genre, dtype: object

# %%
anime_series2 = pd.Series(genre, index = anime, name = 'Anime Genre 2')
anime_series2
# Out:
# My hero Academia                shounen
# Death note                      shuonen
# Sword Art online       Action Adventure
# One-punch Man                    action
# Domestic Girlfriend      shuonen/shoujo
# youri on ice               Sports/josei
# Doraemon                     kodomomuke
# Name: Anime Genre 2, dtype: object

# %%
## Conver to list
anime_series2.tolist()
# Out:
# ['shounen',
#  'shuonen',
#  'Action Adventure',
#  'action',
#  'shuonen/shoujo',
#  'Sports/josei',
#  'kodomomuke']

# %%
## Convert into array
anime_series2.values
# Out:
# array(['shounen', 'shuonen', 'Action Adventure', 'action',
#        'shuonen/shoujo', 'Sports/josei', 'kodomomuke'], dtype=object)

# %%
dic = {
     "My hero Academia"    :           "shounen",
    "Death note"           :           "shuonen",
    "Sword Art online"     :  "Action Adventure",
    "One-punch Man"        :            "action",
    "Domestic Girlfriend"  :    "shuonen/shoujo",
    "youri on ice"         :      "Sports/josei",
    "Doraemon"             :        "kodomomuke", 
}

# %%
pd.Series(dic, name = 'anime genre')
# Out:
# My hero Academia                shounen
# Death note                      shuonen
# Sword Art online       Action Adventure
# One-punch Man                    action
# Domestic Girlfriend      shuonen/shoujo
# youri on ice               Sports/josei
# Doraemon                     kodomomuke
# Name: anime genre, dtype: object

# %% [markdown]
# ## When data is arranged in columns

# %%
names = ['sandip', 'python', 'toshiba']
hobbies = ['Coding', 'Coocking', 'Pc games']
height = ['170cm', '175cm', '172cm']

# %%
information = pd.DataFrame({'Name' : names, 'Hobbies' : hobbies, 'Height' : height})

# %%
information
# Out:
#       Name   Hobbies Height
# 0   sandip    Coding  170cm
# 1   python  Coocking  175cm
# 2  toshiba  Pc games  172cm

# %%
information.set_index('Name', inplace = True)

# %%
information
# Out:
#           Hobbies Height
# Name
# sandip     Coding  170cm
# python   Coocking  175cm
# toshiba  Pc games  172cm

# %% [markdown]
# ## When data is arranged in rows

# %%
row1 = ["sandip", "Coding", "170cm"]
row2 = ["python", "Coocking", "175cm"]
row3 = ["toshiba", "Pc games", "172cm"]

# %%
info2 = pd.DataFrame(data = [row1, row2, row3], columns = ['Name', 'Hobbies', 'Height'])

# %%
info2
# Out:
#       Name   Hobbies Height
# 0   sandip    Coding  170cm
# 1   python  Coocking  175cm
# 2  toshiba  Pc games  172cm

# %%
info2_ser = pd.Series(data = hobbies)
info2_ser
# Out:
# 0      Coding
# 1    Coocking
# 2    Pc games
# dtype: object

# %%
info2_df = pd.Series(data = hobbies, name = "Hobbies").to_frame()
info2_df
# Out:
#     Hobbies
# 0    Coding
# 1  Coocking
# 2  Pc games

# %%
info2_df['Height'] = height
info2_df
# Out:
#     Hobbies Height
# 0    Coding  170cm
# 1  Coocking  175cm
# 2  Pc games  172cm
